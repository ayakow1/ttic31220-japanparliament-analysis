# %% [markdown]
# <a href="https://colab.research.google.com/github/ayakow1/ttic31220-japanparliament-analysis/blob/main/BERTopic_DTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BERTopic DTM analysis for parties

# %% [markdown]
# ## Setup

# %%
# %%capture
# !pip install bertopic

# %%
# %%capture
# !pip install googletrans==3.1.0a0

# %%
from googletrans import Translator

# %%
import pandas as pd
from typing import List
import plotly.graph_objects as go
from sklearn.preprocessing import normalize


def visualize_topics_over_time(topic_model,
                               topics_over_time: pd.DataFrame,
                               top_n_topics: int = None,
                               topics: List[int] = None,
                               normalize_frequency: bool = False,
                               custom_labels: bool = False,
                               title: str = "<b>Topics over Time</b>",
                               topic_lst: List[str] = None, 
                               width: int = 1250,
                               height: int = 450) -> go.Figure:
    """ Visualize topics over time

    Arguments:
        topic_model: A fitted BERTopic instance.
        topics_over_time: The topics you would like to be visualized with the
                          corresponding topic representation
        top_n_topics: To visualize the most frequent topics instead of all
        topics: Select which topics you would like to be visualized
        normalize_frequency: Whether to normalize each topic's frequency individually
        custom_labels: Whether to use custom topic labels that were defined using 
                       `topic_model.set_topic_labels`.
        title: Title of the plot.
        width: The width of the figure.
        height: The height of the figure.

    Returns:
        A plotly.graph_objects.Figure including all traces

    Examples:

    To visualize the topics over time, simply run:

    ```python
    topics_over_time = topic_model.topics_over_time(docs, timestamps)
    topic_model.visualize_topics_over_time(topics_over_time)
    ```

    Or if you want to save the resulting figure:

    ```python
    fig = topic_model.visualize_topics_over_time(topics_over_time)
    fig.write_html("path/to/file.html")
    ```
    <iframe src="../../getting_started/visualization/trump.html"
    style="width:1000px; height: 680px; border: 0px;""></iframe>
    """
    colors = ['#a6cee3','#1f78b4','#b2df8a','#33a02c','#fb9a99']


    # Select topics based on top_n and topics args
    freq_df = topic_model.get_topic_freq()
    freq_df = freq_df.loc[freq_df.Topic != -1, :]
    if topics is not None:
        selected_topics = list(topics)
    elif top_n_topics is not None:
        selected_topics = sorted(freq_df.Topic.to_list()[:top_n_topics])
    else:
        selected_topics = sorted(freq_df.Topic.to_list())

    # Prepare data
    if topic_model.custom_labels_ is not None and custom_labels:
        topic_names = {key: topic_model.custom_labels_[key + topic_model._outliers] for key, _ in topic_model.topic_labels_.items()}
    else:
        topic_names = {key: value[:40] + "..." if len(value) > 40 else value
                       for key, value in topic_model.topic_labels_.items()}
    topics_over_time["Name"] = topics_over_time.Topic.map(topic_names)
    data = topics_over_time.loc[topics_over_time.Topic.isin(selected_topics), :].sort_values(["Topic", "Timestamp"])

    translator = Translator()
    # Add traces
    fig = go.Figure()
    for index, topic in enumerate(data.Topic.unique()):
        trace_data = data.loc[data.Topic == topic, :]
        if not topic_lst:
            topic_name = trace_data.Name.values[0]
            topic_name = topic_name.split('_')[1:]
            topic_name = [translator.translate(k).text for k in topic_name][0]
        else:
            topic_name = topic_lst[index]
        words = trace_data.Words.values
        if normalize_frequency:
            y = normalize(trace_data.Frequency.values.reshape(1, -1))[0]
        else:
            y = trace_data.Frequency
        fig.add_trace(go.Scatter(x=trace_data.Timestamp, y=y,
                                 mode='lines',
                                 marker_color=colors[index % 5],
                                 hoverinfo="text",
                                 name=topic_name,
                                 hovertext=[f'<b>Topic {topic}</b><br>Words: {word}' for word in words]))

    # Styling of the visualization
    fig.update_xaxes(showgrid=True)
    fig.update_yaxes(showgrid=True)
    fig.update_layout(
        yaxis_title="Normalized Frequency" if normalize_frequency else "Frequency",
        title={
            'text': f"{title}",
            'y': .95,
            'x': 0.40,
            'xanchor': 'center',
            'yanchor': 'top',
            'font': dict(
                size=22,
                color="Black")
        },
        template="simple_white",
        width=width,
        height=height,
        hoverlabel=dict(
            bgcolor="white",
            font_size=16,
            font_family="Rockwell"
        ),
        legend=dict(
            title="<b>Global Topic Representation",
        )
    )
    return fig

# %% [markdown]
# ## Restart the Notebook
# After installing BERTopic, some packages that were already loaded were updated and in order to correctly use them, we should now restart the notebook.
#
# From the Menu:
#
# Runtime → Restart Runtime

# %% [markdown]
# ## Data

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# import gensim
# import gensim.corpora as corpora
# from gensim.models.coherencemodel import CoherenceModel
import sqlite3
import pandas as pd
from bertopic import BERTopic
import numpy as np

# %%
# Import Data
use_raw = True
if use_raw:
    name = "raw_speech"
else:
    name = "speech"

# %% [markdown]
# ## Liberal Democratic Party 自由民主党

# %% [markdown]
# ### Topic modeling

# %%
conn = sqlite3.connect(f'/content/drive/MyDrive/議事録/{name}.db')
all = pd.read_sql_query(f'''SELECT * FROM {name} WHERE house ='衆議院' AND party like '%自由民主党%' ''', conn)
docs = all['speech'].to_list()
conn.close()

# %%
# all = all[all['speech_date']>='2012-01-01']
all.head()
# Out:
#                           id house committee  vol speech_date speaker  party  \
# 0  115405254X00320020129_003   衆議院       本会議  第3号  2002-01-29    津島雄二  自由民主党
# 1  115405254X00320020129_010   衆議院       本会議  第3号  2002-01-29    坂本剛二  自由民主党
# 2  115405261X00520020128_201   衆議院     予算委員会  第5号  2002-01-28    北村直人  自由民主党
# 3  115404376X00220020128_301   衆議院   財務金融委員会  第2号  2002-01-28    山本幸三  自由民主党
# 4  115404376X00120020125_147   衆議院   財務金融委員会  第1号  2002-01-25    増原義剛  自由民主党
#
#                                               speech  \
# 0  この 補正予算 二 案 は 、 去る 一月二十一日 本 委員会 に 付託 さ れ 、 一月二...
# 1  本案 は 、 先般 、 政府 により 策定 さ れ た 緊急 対応 プログラム において 推...
# 2      両 案 に対する 質疑 は 終局 し 、 直ちに 採決 さ れん こと を 望み ます 。
# 3  ただいま 議題 と なっ て おり ます 日本電信電話株式会社 の 株式 の 売 払 収入 ...
# 4  先 ほど 財務大臣 より お話 ござい まし た 、 締めて 九 十 四 本 で ござい ま...
#
#                                             morpheme
# 0  連体詞* 名詞固有名詞 名詞数 名詞接尾 助詞係助詞 記号読点 連体詞* 名詞固有名詞 接頭...
# 1  名詞一般 助詞係助詞 記号読点 名詞副詞可能 記号読点 名詞一般 助詞格助詞 名詞サ変接続 ...
# 2  接頭詞名詞接続 名詞一般 助詞格助詞 名詞サ変接続 助詞係助詞 名詞一般 動詞自立 記号読点...
# 3  感動詞* 名詞一般 助詞格助詞 動詞自立 助詞接続助詞 動詞非自立 助動詞* 名詞固有名詞 ...
# 4  名詞一般 助詞副助詞 名詞固有名詞 助詞格助詞 名詞サ変接続 助動詞* 助動詞* 助動詞* ...

# %%
docs = all['speech'].to_list()
len(docs)
# Out:
# 92755

# %%
topic_model = BERTopic(language="multilingual",
                       verbose=True,
                       embedding_model="paraphrase-multilingual-mpnet-base-v2") #https://tech.yellowback.net/posts/sentence-transformers-japanese-models

topics, probs = topic_model.fit_transform(docs) # Input is list type
topic_model.save(f"/content/drive/MyDrive/議事録/BERTopic/model_shuugiin_jimin")
# https://github.com/UKPLab/sentence-transformers/issues/1915 multilingual はエラー
# Out:
# Batches:   0%|          | 0/2899 [00:00<?, ?it/s]
# 2023-05-18 19:17:58,838 - BERTopic - Transformed documents to Embeddings
# 2023-05-18 19:20:08,705 - BERTopic - Reduced dimensionality
# 2023-05-18 19:20:17,064 - BERTopic - Clustered reduced embeddings
# /usr/local/lib/python3.10/dist-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %%
freq = topic_model.get_topic_info(); freq.head(30)
# Out:
#     Topic  Count                       Name
# 0      -1  49173            -1_です_という_ない_こと
# 1       0   2074            0_銀行_金融機関_金融_金利
# 2       1   1344           1_教育_学校_教員_教育基本法
# 3       2   1058           2_年金_社会保障_保険料_給付
# 4       3   1054              3_感謝_皆様_質問_機会
# 5       4    983           4_北朝鮮_韓国_拉致問題_拉致
# 6       5    849                      5____
# 7       6    837            6_道路_高速道路_国道_交通
# 8       7    613             7_雇用_労働者_労働_派遣
# 9       8    485            8_合併_市町村_地方_道州制
# 10      9    466       9_原子力_原発_原子力規制委員会_規制
# 11     10    461           10_ありがとう_ござい_まし_
# 12     11    446   11_感染_新型コロナウイルス_感染症_ウイルス
# 13     12    424      12_デジタル_携帯電話_デジタル化_放送
# 14     13    417             13_予算_年度_財源_金額
# 15     14    405           14_消費税_課税_税制_所得税
# 16     15    385        15_裁判員_裁判員制度_裁判官_裁判
# 17     16    385            16_食品_食育_消費者_牛肉
# 18     17    381       17_排出_温室効果ガス_削減_気候変動
# 19     18    368  18_スポーツ_オリンピック_選手_パラリンピック
# 20     19    363            19_漁業_漁業者_漁船_水産
# 21     20    363             20_医師_病院_医療_患者
# 22     21    362        21_住宅_マンション_建築士_空き家
# 23     22    362             22_呼ぶ_異議_なし_あり
# 24     23    352        23_民主党_マニフェスト_総理_政権
# 25     24    343             24_農業_農協_農地_農家
# 26     25    322            25_障害者_障害_福祉_就労
# 27     26    319             26_森林_木材_林業_間伐
# 28     27    309    27_科学技術_イノベーション_研究開発_研究
# 29     28    306           28_予算_補正予算_年度_編成

# %% [markdown]
# -1 refers to all outliers and should typically be ignored. Next, let's take a look at a frequent topic that were generated:

# %%
topic_model.get_topic(0)  # Select the most frequent topic
# Out:
# [('銀行', 0.006093827701037269),
#  ('金融機関', 0.004965408647422861),
#  ('金融', 0.004804234079759255),
#  ('金利', 0.004027780144501547),
#  ('国債', 0.003811807440085479),
#  ('デフレ', 0.003757975705095921),
#  ('金融庁', 0.0032315158430564163),
#  ('日銀', 0.003178906341293303),
#  ('株式', 0.0030534388106305843),
#  ('融資', 0.0029848166101351468)]

# %% [markdown]
# ### Time series

# %%
topic_model = BERTopic.load("/content/drive/MyDrive/議事録/BERTopic/model_shuugiin_jimin")

# %%
timestamps = all["speech_date"].to_list()
len(docs)
# Out:
# 92755

# %%
# timestamps_ym = []
# for d in timestamps:
#     timestamps_ym.append("-".join(d.split("-")[:-1]))

# %%
timestamps_y = []
for d in timestamps:
    timestamps_y.append(d[:4])

# %%
topics_over_time_y = topic_model.topics_over_time(docs, timestamps_y)
# Out:
# 22it [01:14,  3.37s/it]

# %%
visualize_topics_over_time(topic_model,
                           topics_over_time_y, 
                           topics=[i for i in range(7) if i!=5 and i!=3 and i!=10],
                           topic_lst = ["Bank","Education","Pension","North Korea","Road"],
                           title="Liberal Democratic Party",
                           width=800)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d1b2e4da-fd00-4f56-a5e0-9da751e1d976" class="plotly-graph-div" style="height:450px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1b2e4da-fd00-4f56-a5e0-9da751e1d976")) {                    Plotly.newPlot(                        "d1b2e4da-fd00-4f56-a5e0-9da751e1d976",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: \u9280\u884c, \u682a\u5f0f, \u91d1\u878d\u6a5f\u95a2, \u91d1\u878d, \u30c7\u30d5\u30ec","<b>Topic 0</b><br>Words: \u9280\u884c, \u30c7\u30d5\u30ec, \u682a\u4e3b, \u50b5\u6a29, \u91d1\u878d\u6a5f\u95a2","<b>Topic 0</b><br>Words: \u9280\u884c, \u91d1\u878d\u6a5f\u95a2, \u91d1\u878d, \u878d\u8cc7, \u8b72\u6e21","<b>Topic 0</b><br>Words: \u9280\u884c, \u91d1\u878d, \u682a\u5f0f, \u56fd\u50b5, \u91d1\u878d\u6a5f\u95a2","<b>Topic 0</b><br>Words: \u91d1\u5229, \u91d1\u878d, \u9280\u884c, \u56fd\u50b5, \u91d1\u878d\u6a5f\u95a2","<b>Topic 0</b><br>Words: \u9280\u884c, \u91d1\u878d, \u91d1\u878d\u6a5f\u95a2, \u91d1\u5229, \u4e2d\u5c0f\u4f01\u696d","<b>Topic 0</b><br>Words: \u9280\u884c, \u91d1\u878d, \u91d1\u878d\u6a5f\u95a2, \u91d1\u5229, \u4e2d\u5c0f\u4f01\u696d","<b>Topic 0</b><br>Words: \u9280\u884c, \u91d1\u878d, \u91d1\u878d\u6a5f\u95a2, \u878d\u8cc7, \u682a\u5f0f","<b>Topic 0</b><br>Words: \u9280\u884c, \u91d1\u5229, \u30c7\u30d5\u30ec, \u91d1\u878d, \u91d1\u878d\u6a5f\u95a2","<b>Topic 0</b><br>Words: \u30c7\u30d5\u30ec, \u56fd\u50b5, \u9280\u884c, \u91d1\u878d\u6a5f\u95a2, \u65e5\u9280","<b>Topic 0</b><br>Words: \u30c7\u30d5\u30ec, \u65e5\u9280, \u91d1\u5229, \u7269\u4fa1, \u91d1\u878d\u6a5f\u95a2","<b>Topic 0</b><br>Words: \u91d1\u878d\u6a5f\u95a2, \u9280\u884c, \u30c7\u30d5\u30ec, \u7269\u4fa1, \u91d1\u878d","<b>Topic 0</b><br>Words: \u53d6\u7de0\u5f79, \u682a\u4e3b, \u50b5\u6a29\u8005, \u793e\u5916\u53d6\u7de0\u5f79, \u4f1a\u793e","<b>Topic 0</b><br>Words: \u5c55\u793a\u4f1a, \u682a\u4e3b, \u9280\u884c, \u878d\u8cc7, \u4fdd\u8a3c","<b>Topic 0</b><br>Words: \u4fdd\u8a3c, \u91d1\u878d\u6a5f\u95a2, \u56fd\u50b5, \u767a\u884c, \u30de\u30a4\u30ca\u30b9\u91d1\u5229","<b>Topic 0</b><br>Words: \u4fdd\u8a3c\u5354\u4f1a, \u91d1\u878d\u6a5f\u95a2, gdp, \u9280\u884c, pb","<b>Topic 0</b><br>Words: \u4eee\u60f3\u901a\u8ca8, \u91d1\u878d\u6a5f\u95a2, \u91d1\u878d\u5e81, \u501f\u91d1, \u9280\u884c","<b>Topic 0</b><br>Words: \u91d1\u878d\u6a5f\u95a2, \u50b5\u52d9\u8005, \u7d71\u8a08, \u793e\u5916\u53d6\u7de0\u5f79, \u9280\u884c","<b>Topic 0</b><br>Words: \u4f01\u696d, \u91d1\u878d\u6a5f\u95a2, \u653e\u6d41, \u5229\u76ca\u7387, \u878d\u8cc7","<b>Topic 0</b><br>Words: \u56fd\u50b5, \u767a\u884c, \u9280\u884c, \u878d\u8cc7, \u91d1\u878d\u6a5f\u95a2","<b>Topic 0</b><br>Words: \u6697\u53f7, \u8cc3\u4e0a\u3052, \u8cc7\u672c\u4e3b\u7fa9, \u91d1\u878d\u6a5f\u95a2, \u5206\u914d","<b>Topic 0</b><br>Words: \u4fdd\u8a3c, \u63a8\u8a08, gdp\u30ae\u30e3\u30c3\u30d7, \u878d\u8cc7, \u91d1\u878d\u6a5f\u95a2"],"marker":{"color":"#a6cee3"},"mode":"lines","name":"Bank","x":["2002-01-01T00:00:00","2003-01-01T00:00:00","2004-01-01T00:00:00","2005-01-01T00:00:00","2006-01-01T00:00:00","2007-01-01T00:00:00","2008-01-01T00:00:00","2009-01-01T00:00:00","2010-01-01T00:00:00","2011-01-01T00:00:00","2012-01-01T00:00:00","2013-01-01T00:00:00","2014-01-01T00:00:00","2015-01-01T00:00:00","2016-01-01T00:00:00","2017-01-01T00:00:00","2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00"],"y":[134,100,102,134,161,108,112,126,164,235,183,62,45,35,89,31,41,60,42,51,52,7],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: \u6559\u80b2, \u5b66\u6821, \u6559\u54e1, \u5b66\u7fd2\u6307\u5c0e\u8981\u9818, \u5b50\u4f9b\u305f\u3061","<b>Topic 1</b><br>Words: \u6559\u80b2, \u6559\u80b2\u57fa ...

# %% [markdown]
# ## Check which parties are relevent

# %%
conn = sqlite3.connect(f'/content/drive/MyDrive/議事録/{name}.db')
all2 = pd.read_sql_query(f'''SELECT * FROM {name} WHERE house ='衆議院' AND party not like '%自由民主党%' ''', conn)
conn.close()

# %%
all2["year"] = all2["speech_date"].str.slice(start=0,stop=4)

# %%
all2[["party","year","id"]].groupby(["party","year"]).count()
# Out:
#                      id
# party        year
# おおさか維新の会     2015     7
#              2016  1506
# たちあがれ日本      2011     3
#              2012     2
# たちあがれ日本・新党改革 2011     3
# ...                 ...
# 自由党          2002  3654
#              2003  2777
#              2016    27
#              2017   245
#              2018   201
#
# [229 rows x 1 columns]

# %%
all2[["party","id"]].groupby("party").count().sort_values(by="id",ascending=False)
# Out:
#                     id
# party
# 民主党・無所属クラブ      134720
# 日本共産党            63669
# 公明党              42286
# 日本維新の会           23664
# 立憲民主党・無所属        21490
# ...                ...
# 日本を元気にする会・無所属会       2
# 民進党・新緑風会             2
# 新党改革・無所属の会           1
# 立憲民主党・民友会            1
# 立憲・国民．新緑風会・社民        1
#
# [68 rows x 1 columns]

# %% [markdown]
# ## New Komeito 公明党

# %%
conn = sqlite3.connect(f'/content/drive/MyDrive/議事録/{name}.db')
all3 = pd.read_sql_query(f'''SELECT * FROM {name} WHERE house ='衆議院' AND party = '公明党' ''', conn)
conn.close()

# %%
docs = all3['speech'].to_list()
len(docs)
# Out:
# 42286

# %%
topic_model3 = BERTopic(language="multilingual",
                       verbose=True,
                       embedding_model="paraphrase-multilingual-mpnet-base-v2") #https://tech.yellowback.net/posts/sentence-transformers-japanese-models

topics3, probs3 = topic_model3.fit_transform(docs) # Input is list type
topic_model3.save(f"/content/drive/MyDrive/議事録/BERTopic/model_shuugiin_koumei")
# https://github.com/UKPLab/sentence-transformers/issues/1915 multilingual はエラー
# Out:
# Downloading (…)9e268/.gitattributes:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)f2cd19e268/README.md:   0%|          | 0.00/3.77k [00:00<?, ?B/s]
# Downloading (…)cd19e268/config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)9e268/tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/402 [00:00<?, ?B/s]
# Downloading (…)d19e268/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Batches:   0%|          | 0/1322 [00:00<?, ?it/s]
# 2023-05-19 14:57:59,683 - BERTopic - Transformed documents to Embeddings
# 2023-05-19 14:58:55,914 - BERTopic - Reduced dimensionality
# 2023-05-19 14:59:00,259 - BERTopic - Clustered reduced embeddings
# /usr/local/lib/python3.10/dist-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.

# %%
freq = topic_model3.get_topic_info(); freq.head(30)
# Out:
#     Topic  Count                               Name
# 0      -1  20225                    -1_という_ます_です_こと
# 1       0    876                    0_金融機関_銀行_金融_金利
# 2       1    734                      1_災害_地震_被害_避難
# 3       2    730                    2_学校_教育_子供たち_教員
# 4       3    681                      3_病院_患者_医療_医師
# 5       4    601                   4_年金_保険料_制度_社会保障
# 6       5    599                  5_ありがとう_ござい_まし_拍手
# 7       6    591                    6_市町村_地方_地域_自治体
# 8       7    561                     7_参考人_先生_貴重_意見
# 9       8    458                     8_原子力_原発_規制_事故
# 10      9    411          9_再生可能エネルギー_電力_エネルギー_電気料金
# 11     10    388              10_住宅_マンション_賃貸住宅_建てかえ
# 12     11    374                  11_北朝鮮_韓国_発射_拉致問題
# 13     12    355                  12_農業_農地_農家_農業委員会
# 14     13    314                   13_目標_排出_削減_気候変動
# 15     14    296                 14_中小企業_小規模_企業_事業者
# 16     15    285                15_消費税_軽減税率_税額控除_給付
# 17     16    282                     16_予算_年度_財源_です
# 18     17    257                17_裁判官_裁判員制度_裁判所_事件
# 19     18    246                  18_障害者_福祉_障害_サービス
# 20     19    230                  19_保育_児童手当_子供_子育て
# 21     20    224               20_ワクチン_接種_予防接種_定期接種
# 22     21    219                 21_憲法_憲法改正_国民投票_議論
# 23     22    215                 22_消費者_消費者庁_勧誘_事業者
# 24     23    209                 23_派遣_雇用_派遣労働者_派遣先
# 25     24    199                  24_介護_介護保険_医療費_医療
# 26     25    190                   25_被災_お見舞い_復興_総理
# 27     26    185                  26_船舶_港湾_海上保安庁_海賊
# 28     27    178  27_感染_新型コロナウイルス_ワクチン_新型コロナウイルス感染症
# 29     28    172                 28_環境_環境大臣_環境省_epa

# %%
topic_model3 = BERTopic.load("/content/drive/MyDrive/議事録/BERTopic/model_shuugiin_koumei")

# %%
timestamps = all3["speech_date"].to_list()
len(docs)
# Out:
# 42286

# %%
timestamps_y = []
for d in timestamps:
    timestamps_y.append(d[:4])

# %%
topics_over_time_y = topic_model3.topics_over_time(docs, timestamps_y)
# Out:
# 22it [00:29,  1.34s/it]

# %%
visualize_topics_over_time(topic_model3,
                           topics_over_time_y, 
                           topics=[i for i in range(5)],
                           title="New Komeito",
                           topic_lst = ["Bank", "Disaster", "School", "Hospital", "Pension"],
                           width=800)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="542ae64f-c795-4cab-824f-28f7c0599f32" class="plotly-graph-div" style="height:450px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("542ae64f-c795-4cab-824f-28f7c0599f32")) {                    Plotly.newPlot(                        "542ae64f-c795-4cab-824f-28f7c0599f32",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: \u30c7\u30d5\u30ec, \u4e0d\u826f\u50b5\u6a29, \u9280\u884c, \u91d1\u878d\u6a5f\u95a2, \u65e5\u9280","<b>Topic 0</b><br>Words: \u9280\u884c, \u682a\u5f0f, \u30c7\u30d5\u30ec, \u91d1\u878d\u6a5f\u95a2, \u4fdd\u6709","<b>Topic 0</b><br>Words: \u91d1\u878d\u6a5f\u95a2, \u30c7\u30d5\u30ec, \u4fdd\u8a3c, \u878d\u8cc7, \u91d1\u878d","<b>Topic 0</b><br>Words: \u6301\u3061\u682a\u4f1a\u793e, \u9280\u884c, \u58f2\u5374, \u91d1\u878d, \u90f5\u8caf","<b>Topic 0</b><br>Words: \u91d1\u5229, \u91d1\u878d, \u8cb8\u91d1\u696d\u8005, \u91d1\u878d\u6a5f\u95a2, \u304a\u308b","<b>Topic 0</b><br>Words: \u91d1\u878d\u6a5f\u95a2, \u91d1\u878d, \u6bd4\u7387, \u5b8c\u5168\u6c11\u55b6\u5316, \u50b5\u6a29","<b>Topic 0</b><br>Words: \u91d1\u878d\u6a5f\u95a2, \u91d1\u878d, \u91d1\u5229, \u4e2d\u5c0f\u4f01\u696d, \u878d\u8cc7","<b>Topic 0</b><br>Words: \u91d1\u878d, \u91d1\u878d\u6a5f\u95a2, \u56fd\u50b5, \u91d1\u5229, \u9280\u884c","<b>Topic 0</b><br>Words: \u4fdd\u8a3c, \u56fd\u50b5, \u30de\u30cb\u30d5\u30a7\u30b9\u30c8, \u65e5\u9280, \u91d1\u5229","<b>Topic 0</b><br>Words: \u91d1\u878d\u6a5f\u95a2, \u50b5\u52d9, \u91d1\u5229, \u91d1\u878d, \u9280\u884c","<b>Topic 0</b><br>Words: \u30c7\u30d5\u30ec, \u91d1\u5229, \u91d1\u878d, \u91d1\u878d\u6a5f\u95a2, \u9280\u884c","<b>Topic 0</b><br>Words: \u65e5\u9280, \u91d1\u878d\u6a5f\u95a2, \u30c7\u30d5\u30ec, \u91d1\u5229, \u9280\u884c","<b>Topic 0</b><br>Words: \u91d1\u878d\u6a5f\u95a2, \u306a\u3069, \u7dcf\u88c1, \u4e2d\u5c0f\u4f01\u696d, \u5411\u3051","<b>Topic 0</b><br>Words: \u91d1\u5229, \u91d1\u878d\u6a5f\u95a2, \u5ef6\u6ede, \u50b5\u6a29, \u5546\u54c1\u5238","<b>Topic 0</b><br>Words: \u50b5\u6a29, \u50b5\u52d9\u8005, \u50b5\u6a29\u8b72\u6e21, \u6297\u5f01, \u8b72\u308a\u53d7\u3051","<b>Topic 0</b><br>Words: \u91d1\u878d\u6a5f\u95a2, \u9280\u884c, \u4fdd\u8a3c, \u4fe1\u7528, \u8cc7\u91d1\u7e70\u308a","<b>Topic 0</b><br>Words: \u7dcf\u88c1, etf, \u4eee\u60f3\u901a\u8ca8, \u8cc3\u91d1, \u878d\u8cc7","<b>Topic 0</b><br>Words: \u50b5\u6a29, \u5dee\u62bc, \u682a\u4e3b\u7dcf\u4f1a, \u5be9\u5c0b, \u9280\u884c","<b>Topic 0</b><br>Words: \u30ed\u30fc\u30f3, \u8fd4\u6e08, \u91d1\u878d\u6a5f\u95a2, \u91d1\u878d\u5e81, \u30dc\u30fc\u30ca\u30b9","<b>Topic 0</b><br>Words: \u8cb8\u4ed8\u3051, \u91d1\u878d\u30bb\u30f3\u30bf\u30fc, \u5730\u57df\u9280\u884c, \u8cc7\u91d1, \u30af\u30e9\u30a6\u30c9\u30d5\u30a1\u30f3\u30c7\u30a3\u30f3\u30b0","<b>Topic 0</b><br>Words: \u7269\u4fa1, \u91d1\u878d\u6a5f\u95a2, \u91d1\u5229, \u4e0a\u6607, \u7269\u4fa1\u4e0a\u6607","<b>Topic 0</b><br>Words: \u30ea\u30b9\u30b1, \u304a\u7b54\u3048, \u3057\u308d, \u4e00\u5f8b, \u306f\u305a"],"marker":{"color":"#a6cee3"},"mode":"lines","name":"Bank","x":["2002-01-01T00:00:00","2003-01-01T00:00:00","2004-01-01T00:00:00","2005-01-01T00:00:00","2006-01-01T00:00:00","2007-01-01T00:00:00","2008-01-01T00:00:00","2009-01-01T00:00:00","2010-01-01T00:00:00","2011-01-01T00:00:00","2012-01-01T00:00:00","2013-01-01T00:00:00","2014-01-01T00:00:00","2015-01-01T00:00:00","2016-01-01T00:00:00","2017-01-01T00:00:00","2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00"],"y":[75,51,45,54,61,46,47,57,68,105,64,38,22,26,22,18,15,15,12,15,19,1],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: \u5730\u9707, \u904a\u6c34\u5730, \u6d88\u9632\u56e3, \u6c34\u8d8a, \u4e88\u77e5"," ...

# %% [markdown]
# ## Japanese Communist Party 日本共産党

# %%
import gc

del all
del all2
del all3

gc.collect()
# Out:
# 358

# %%
conn = sqlite3.connect(f'/content/drive/MyDrive/議事録/{name}.db')
all4 = pd.read_sql_query(f'''SELECT * FROM {name} WHERE house ='衆議院' AND party = '日本共産党' ''', conn)
conn.close()

# %%
docs = all4['speech'].to_list()
len(docs)
# Out:
# 63669

# %%
topic_model4 = BERTopic(language="multilingual",
                       verbose=True,
                       embedding_model="paraphrase-multilingual-mpnet-base-v2") #https://tech.yellowback.net/posts/sentence-transformers-japanese-models

topics4, probs4 = topic_model4.fit_transform(docs) # Input is list type
topic_model4.save(f"/content/drive/MyDrive/議事録/BERTopic/model_shuugiin_kyousan")
# https://github.com/UKPLab/sentence-transformers/issues/1915 multilingual はエラー
# Out:
# Batches:   0%|          | 0/1990 [00:00<?, ?it/s]
# 2023-05-19 15:11:11,996 - BERTopic - Transformed documents to Embeddings
# 2023-05-19 15:12:05,018 - BERTopic - Reduced dimensionality
# 2023-05-19 15:12:10,586 - BERTopic - Clustered reduced embeddings
# /usr/local/lib/python3.10/dist-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.

# %%
freq = topic_model4.get_topic_info(); freq.head(30)
# Out:
#     Topic  Count                    Name
# 0      -1  33989         -1_です_という_ない_こと
# 1       0   2165          0_労働者_雇用_労働_賃金
# 2       1   1799           1_言っ_大臣_です_ない
# 3       2    917          2_消費税_増税_減税_転嫁
# 4       3    913           3_学校_教育_学級_教員
# 5       4    748         4_保育_子供_保育所_保育士
# 6       5    726          5_飛行_訓練_米軍機_米軍
# 7       6    641           6_事件_裁判_警察_犯罪
# 8       7    600         7_銀行_金融機関_金利_融資
# 9       8    480         8_住宅_家賃_公営住宅_入居
# 10      9    479           9_農業_農家_農地_農協
# 11     10    453      10_参考人_貴重_ありがとう_参考
# 12     11    430       11_大臣_お願い_委員長_終わり
# 13     12    417        12_奨学金_大学_学生_授業料
# 14     13    396         13_原発_原子力_稼働_規制
# 15     14    388         14_北朝鮮_カ国_協議_解決
# 16     15    372          15_ダム_治水_水道_河川
# 17     16    333      16_年金_厚生年金_給付_公的年金
# 18     17    325      17_ありがとう_ござい_まし_枯渇
# 19     18    316      18_tpp_関税_交渉_tpp交渉
# 20     19    262  19_感染_感染者_対策_新型コロナウイルス
# 21     20    258       20_献金_政党助成金_政党_団体
# 22     21    251         21_漁業_漁業者_漁協_漁民
# 23     22    251      22_女性_男女_女性差別_賃金格差
# 24     23    249      23_イラク_占領_戦争_イラク戦争
# 25     24    245         24_年度_予算_ユーロ_献金
# 26     25    234         25_避難_被災者_被災_支援
# 27     26    231        26_jr_鉄道_路線_jr東海
# 28     27    226         27_排出_目標_削減_co2
# 29     28    222       28_核兵器_被爆_廃絶_核保有国

# %%
topic_model4 = BERTopic.load("/content/drive/MyDrive/議事録/BERTopic/model_shuugiin_kyousan")

# %%
timestamps = all4["speech_date"].to_list()
len(docs)
# Out:
# 63669

# %%
timestamps_y = []
for d in timestamps:
    timestamps_y.append(d[:4])

# %%
topics_over_time_y = topic_model4.topics_over_time(docs, timestamps_y)
# Out:
# 22it [00:33,  1.54s/it]

# %%
visualize_topics_over_time(topic_model4, topics_over_time_y, 
                           topics_over_time_y, 
                           topics=[i for i in range(6) if i!=1 and i!=10 and i!=11],
                           topic_lst=["Labor", "Sales Tax", "School", "Daycare", "U.S. Army"],
                           title="Japanese Communist Party",
                           width=800)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="83e623d9-58ca-4e57-bdc3-3adf90379df6" class="plotly-graph-div" style="height:450px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83e623d9-58ca-4e57-bdc3-3adf90379df6")) {                    Plotly.newPlot(                        "83e623d9-58ca-4e57-bdc3-3adf90379df6",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: \u52b4\u50cd\u8005, \u96c7\u7528, \u52b4\u50cd, \u30b5\u30fc\u30d3\u30b9\u6b8b\u696d, \u8cc3\u91d1","<b>Topic 0</b><br>Words: \u52b4\u50cd\u8005, \u89e3\u96c7, \u52b4\u50cd, \u8cc3\u91d1, \u96c7\u7528","<b>Topic 0</b><br>Words: \u52b4\u50cd\u8005, \u96c7\u7528, \u52b4\u50cd, \u8077\u54e1, \u6642\u9593","<b>Topic 0</b><br>Words: \u52b4\u50cd\u6642\u9593, \u52b4\u50cd\u8005, \u96c7\u7528, \u52b4\u50cd, \u8cc3\u91d1","<b>Topic 0</b><br>Words: \u8acb\u8ca0, \u52b4\u50cd, \u52b4\u50cd\u8005, \u96c7\u7528, \u6d3e\u9063","<b>Topic 0</b><br>Words: \u52b4\u50cd\u8005, \u52b4\u50cd, \u96c7\u7528, \u8acb\u8ca0, \u6d3e\u9063","<b>Topic 0</b><br>Words: \u6d3e\u9063, \u96c7\u7528, \u52b4\u50cd\u8005, \u65e5\u96c7\u3044\u6d3e\u9063, \u52b4\u50cd","<b>Topic 0</b><br>Words: \u6d3e\u9063, \u96c7\u7528, \u52b4\u50cd\u8005, \u89e3\u96c7, \u52b4\u50cd","<b>Topic 0</b><br>Words: \u96c7\u7528, \u6d3e\u9063, \u52b4\u50cd\u8005, \u696d\u52d9, \u52b4\u50cd","<b>Topic 0</b><br>Words: \u6d3e\u9063, \u96c7\u7528, \u52b4\u50cd\u8005, \u52b4\u50cd, \u6d3e\u9063\u5148","<b>Topic 0</b><br>Words: \u52b4\u50cd\u8005, \u56fd\u5bb6\u516c\u52d9\u54e1, \u96c7\u7528, \u8cc3\u91d1, \u8cc3\u4e0b\u3052","<b>Topic 0</b><br>Words: \u8cc3\u91d1, \u96c7\u7528, \u52b4\u50cd\u8005, \u7d66\u4e0e, \u52b4\u50cd","<b>Topic 0</b><br>Words: \u96c7\u7528, \u52b4\u50cd\u8005, \u6d3e\u9063, \u8cc3\u91d1, \u7d66\u4e0e","<b>Topic 0</b><br>Words: \u6d3e\u9063, \u96c7\u7528, \u6b63\u793e\u54e1, \u6d3e\u9063\u52b4\u50cd\u8005, \u52b4\u50cd\u8005","<b>Topic 0</b><br>Words: \u52b4\u50cd\u8005, \u6642\u9593, \u8cc3\u91d1, \u96c7\u7528, \u52b4\u50cd","<b>Topic 0</b><br>Words: \u6642\u9593, \u52b4\u50cd\u8005, \u8077\u54e1, \u52b4\u50cd\u6642\u9593, \u96c7\u7528","<b>Topic 0</b><br>Words: \u88c1\u91cf\u52b4\u50cd\u5236, \u6642\u9593, \u52b4\u50cd\u6642\u9593, \u52b4\u50cd\u8005, \u52b4\u50cd","<b>Topic 0</b><br>Words: \u6700\u4f4e\u8cc3\u91d1, \u8cc3\u91d1, \u52b4\u50cd\u8005, \u96c7\u7528, \u5909\u5f62\u52b4\u50cd\u6642\u9593\u5236","<b>Topic 0</b><br>Words: \u96c7\u7528, \u52b4\u50cd\u8005, \u8cc3\u91d1, \u4f11\u696d\u624b\u5f53, \u52b4\u50cd","<b>Topic 0</b><br>Words: \u30b7\u30d5\u30c8, \u96c7\u7528, \u52b4\u50cd\u8005, \u8cc3\u91d1, \u6642\u9593","<b>Topic 0</b><br>Words: \u6700\u4f4e\u8cc3\u91d1, \u8cc3\u4e0a\u3052, \u8cc3\u91d1, \u5931\u696d\u7d66\u4ed8, \u96c7\u7528","<b>Topic 0</b><br>Words: \u6700\u4f4e\u8cc3\u91d1, \u671f\u9593, \u6642\u9593, \u9762\u63a5, \u8077\u54e1"],"marker":{"color":"#a6cee3"},"mode":"lines","name":"Labor","x":["2002-01-01T00:00:00","2003-01-01T00:00:00","2004-01-01T00:00:00","2005-01-01T00:00:00","2006-01-01T00:00:00","2007-01-01T00:00:00","2008-01-01T00:00:00","2009-01-01T00:00:00","2010-01-01T00:00:00","2011-01-01T00:00:00","2012-01-01T00:00:00","2013-01-01T00:00:00","2014-01-01T00:00:00","2015-01-01T00:00:00","2016-01-01T00:00:00","2017-01-01T00:00:00","2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00"],"y":[123,187,51,66,75,155,76,118,87,41,58,97,109,156,149,131,145,99,109,51,72,10],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 2</b><br>Words: \u9023\u7d50\u7d0d\u7a0e, \u6d88\u8cbb\u7a0e, \u7a0e\u5236, \u6e1b\u7a0e, \u5897\u7a0e","<b>Topic 2</b><br>Words: \u6d88\u8cbb\u7a0e, \u8ee2\u5ac1, \u5897\u7a0e, \u6e1b\u7a0e, \u6cd5\u4eba\u7a0e","<b>Topic 2</b><br>Words: \u6 ...

# %% [markdown]
# ## Democratic Party of Japan + Constitutional Democratic Party of Japan 民主党+立憲民主党

# %%
conn = sqlite3.connect(f'/content/drive/MyDrive/議事録/{name}.db')
all5 = pd.read_sql_query(f'''SELECT * FROM {name} WHERE house ='衆議院' AND (party = '民主党・無所属クラブ' OR party = '立憲民主党・無所属')''', conn)
conn.close()

# %%
docs = all5['speech'].to_list()
len(docs)
# Out:
# 156210

# %%
topic_model5 = BERTopic(language="multilingual",
                       verbose=True,
                       embedding_model="paraphrase-multilingual-mpnet-base-v2") #https://tech.yellowback.net/posts/sentence-transformers-japanese-models

topics5, probs5 = topic_model5.fit_transform(docs) # Input is list type
topic_model5.save(f"/content/drive/MyDrive/議事録/BERTopic/model_shuugiin_minshu")
# https://github.com/UKPLab/sentence-transformers/issues/1915 multilingual はエラー

# %%
topic_model5 = BERTopic.load("/content/drive/MyDrive/議事録/BERTopic/model_shuugiin_minshu")

# %%
freq = topic_model5.get_topic_info(); freq.head(30)
# Out:
#     Topic  Count                         Name
# 0      -1  90112              -1_です_という_ない_こと
# 1       0   4210               0_警察_裁判_裁判官_捜査
# 2       1   3948                1_農業_農家_農地_農協
# 3       2   2067              2_消費税_税制_課税_交付税
# 4       3   1822           3_年金_国民年金_厚生年金_保険料
# 5       4   1650              4_雇用_労働_労働者_正社員
# 6       5   1532             5_北朝鮮_韓国_拉致_拉致問題
# 7       6   1416             6_学校_教育_教育基本法_教員
# 8       7   1351            7_ありがとう_ござい_まし_拍手
# 9       8   1223              8_数字_データ_ぐらい_人口
# 10      9   1049                9_予算_年度_お金_金額
# 11     10    896             10_空港_航空_航空会社_羽田
# 12     11    880              11_合併_市町村_都市_地方
# 13     12    833           12_予算_特別会計_補正予算_年度
# 14     13    766               13_法案_国会_審議_成立
# 15     14    639             14_国債_銀行_不良債権_融資
# 16     15    634  15_感染_新型インフルエンザ_鳥インフルエンザ_変異
# 17     16    622          16_ワクチン_接種_予防接種_副反応
# 18     17    619              17_障害者_障害_福祉_雇用
# 19     18    614        18_個人情報_秘密_情報_個人情報保護法
# 20     19    588        19_海賊_海上保安庁_船舶_海上警備行動
# 21     20    536    20_消費者_消費者庁_適格消費者団体_消費者行政
# 22     21    524        21_排出_co2_地球温暖化_京都議定書
# 23     22    511           22_放送_電波_電波利用料_放送法
# 24     23    492            23_幾ら_では_ください_金融庁
# 25     24    478          24_原子力_原発_原子力発電所_稼働
# 26     25    476             25_nhk_会長_受信料_放送
# 27     26    452           26_イラク_自衛隊_国連_復興支援
# 28     27    426       27_武力攻撃_集団的自衛権_行使_武力行使
# 29     28    424          28_郵政民営化_郵便局_民営化_公社

# %%
timestamps = all5["speech_date"].to_list()
len(docs)
# Out:
# 156210

# %%
timestamps_y = []
for d in timestamps:
    timestamps_y.append(d[:4])

# %%
topics_over_time_y = topic_model5.topics_over_time(docs, timestamps_y)
# Out:
# 17it [01:24,  4.95s/it]

# %%
visualize_topics_over_time(topic_model5, 
                           topics_over_time_y, 
                            topics=[i for i in range(5)],
                            title="Democratic Party of Japan",
                           topic_lst=["Police", "Agriculture", "Sales Tax", "Pension", "Labor"], 
                            width=800)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3debc82a-1939-4737-8096-2a717611cadc" class="plotly-graph-div" style="height:450px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3debc82a-1939-4737-8096-2a717611cadc")) {                    Plotly.newPlot(                        "3debc82a-1939-4737-8096-2a717611cadc",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: \u8b66\u5bdf, \u72af\u7f6a, \u88c1\u5224\u5b98, \u6cd5\u66f9, \u88c1\u5224","<b>Topic 0</b><br>Words: \u4ef2\u88c1, \u88c1\u5224\u5b98, \u88c1\u5224, \u4e8b\u4ef6, \u88c1\u5224\u6240","<b>Topic 0</b><br>Words: \u88c1\u5224\u54e1, \u88c1\u5224\u5b98, \u8b66\u5bdf, \u88c1\u5224, \u5f01\u8b77\u58eb","<b>Topic 0</b><br>Words: \u8b66\u5bdf, \u72af\u7f6a, \u88c1\u5224\u5b98, \u53d7\u5211\u8005, \u5211\u52d9\u6240","<b>Topic 0</b><br>Words: \u8b66\u5bdf, \u635c\u67fb, \u72af\u7f6a, \u7559\u7f6e, \u88c1\u5224","<b>Topic 0</b><br>Words: \u88ab\u5bb3\u8005, \u72af\u7f6a\u88ab\u5bb3\u8005, \u8b66\u5bdf, \u88c1\u5224, \u691c\u5bdf\u5b98","<b>Topic 0</b><br>Words: \u88c1\u5224\u5b98, \u8b66\u5bdf, \u88ab\u5bb3\u8005, \u88c1\u5224\u54e1\u5236\u5ea6, \u4e8b\u4ef6","<b>Topic 0</b><br>Words: \u88c1\u5224\u54e1\u5236\u5ea6, \u88c1\u5224, \u4e8b\u4ef6, \u8b66\u5bdf, \u88c1\u5224\u5b98","<b>Topic 0</b><br>Words: \u53f8\u6cd5, \u691c\u5bdf, \u8d77\u8a34, \u516c\u8a34\u6642\u52b9, \u88c1\u5224\u5b98","<b>Topic 0</b><br>Words: \u691c\u5bdf, \u6cd5\u66f9, \u975e\u8a1f\u4e8b\u4ef6\u624b\u7d9a\u6cd5, \u6751\u6728, \u518d\u5be9","<b>Topic 0</b><br>Words: \u6cd5\u66f9, \u990a\u6210, \u53f8\u6cd5\u4fee\u7fd2\u751f, \u4fee\u7fd2, \u7d4c\u6e08\u7684","<b>Topic 0</b><br>Words: \u88c1\u5224\u5b98, \u5f01\u8b77\u58eb, \u5224\u6c7a, \u88c1\u5224, \u6cd5\u66f9","<b>Topic 0</b><br>Words: \u518d\u5be9, \u5be9\u7406, \u5211\u52d9\u6240, \u6b7b\u5211, \u88c1\u5224","<b>Topic 0</b><br>Words: \u53f8\u6cd5\u53d6\u5f15, \u53d6\u308a\u8abf\u3079, \u635c\u67fb, \u4e8b\u4ef6, \u8b66\u5bdf","<b>Topic 0</b><br>Words: \u8b66\u5bdf, \u88c1\u5224, \u30b9\u30c8\u30fc\u30ab\u30fc, \u691c\u5bdf, \u72af\u7f6a","<b>Topic 0</b><br>Words: \u88c1\u5224, \u88c1\u5224\u5b98, \u51e6\u7f70, \u4fae\u8fb1\u7f6a, \u8b66\u5bdf","<b>Topic 0</b><br>Words: \u9577\u5d0e, \u88ab\u7206\u8005, \u30ad\u30ed, \u5e83\u5cf6, \u7206\u5fc3\u5730"],"marker":{"color":"#a6cee3"},"mode":"lines","name":"Police","x":["2002-01-01T00:00:00","2003-01-01T00:00:00","2004-01-01T00:00:00","2005-01-01T00:00:00","2006-01-01T00:00:00","2007-01-01T00:00:00","2008-01-01T00:00:00","2009-01-01T00:00:00","2010-01-01T00:00:00","2011-01-01T00:00:00","2012-01-01T00:00:00","2013-01-01T00:00:00","2014-01-01T00:00:00","2015-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00"],"y":[239,316,855,456,428,385,221,146,73,76,38,115,153,275,187,239,8],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: \u8fb2\u696d, \u91ce\u83dc, \u8fb2\u5bb6, \u8fb2\u6c34\u7701, \u8fb2\u85ac","<b>Topic 1</b><br>Words: \u8fb2\u696d, \u98df\u54c1, \u8fb2\u5bb6, \u8fb2\u6c34\u7701, \u8f38\u5165","<b>Topic 1</b><br>Words: \u8fb2\u696d, \u8fb2\u5354, \u8fb2\u5bb6, \u8fb2\u5730, \u8f38\u5165","<b>Topic 1</b><br>Words: \u8fb2\u696d, \u8fb2\u5730, \u8fb2\u5bb6, \u62c5\u3044\u624b, \u81ea\u7d66\u7387","<b>Topic 1</b><br>Words: \u8fb2\u696d, \u8fb2\u5bb6, \u8fb2\u5730, \u8f38\u5165, \u751f\u7523","<b>Topic 1</b><br>Words: \u8fb2\u5bb6, \u8fb2\u696d, \u8fb2\u5354, \u98df\u54c1, \u98fc\u6599","<b>Topic 1</b><br>Words: \u8fb2\u696d, \u8fb2\u5bb6, \u8fb2\u6c34\u7701, \u98fc\u6599, \u30af\u30ed\u30fc\u30f3","<b>Topic 1</b><br>Words: \u8fb2\u5730, \u8fb2\u696d, \u8fb2\u5bb6, \u8fb2\u6c34\u7701, \u8fb2\u5730\u6cd5","<b>Topic 1</b><br>Words: \u8fb2\u696d, \u8fb2\u5bb6, \u53e3\u8e44\u75ab, \u8fb2\u6751, \u516d\u6b21\u7523\u6 ...

# %% [markdown]
# ## Train additional model for next analysis

# %%
conn = sqlite3.connect(f'/content/drive/MyDrive/議事録/{name}.db')
all6 = pd.read_sql_query(f'''SELECT * FROM {name} WHERE house ='衆議院' AND speech_date >= '2020-01-01' AND speech_date <= '2023-04-31' ''', conn)
conn.close()

# %%
len(all5)
# Out:
# 71357

# %%
docs = all6['speech'].to_list()

# %%
len(docs)
# Out:
# 71357

# %%
topic_model5 = BERTopic(language="multilingual",
                       verbose=True,
                       embedding_model="paraphrase-multilingual-mpnet-base-v2") #https://tech.yellowback.net/posts/sentence-transformers-japanese-models

topics5, probs5 = topic_model5.fit_transform(docs) # Input is list type
topic_model5.save(f"/content/drive/MyDrive/議事録/BERTopic/model_shuugiin_3y")
# Out:
# Downloading (…)9e268/.gitattributes:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)f2cd19e268/README.md:   0%|          | 0.00/3.77k [00:00<?, ?B/s]
# Downloading (…)cd19e268/config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)9e268/tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/402 [00:00<?, ?B/s]
# Downloading (…)d19e268/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Batches:   0%|          | 0/2230 [00:00<?, ?it/s]
# 2023-05-19 00:15:13,000 - BERTopic - Transformed documents to Embeddings
# 2023-05-19 00:17:28,938 - BERTopic - Reduced dimensionality
# 2023-05-19 00:17:37,998 - BERTopic - Clustered reduced embeddings
# /usr/local/lib/python3.10/dist-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %%
freq = topic_model5.get_topic_info(); freq.head(30)
# Out:
#     Topic  Count                             Name
# 0      -1  34792                  -1_です_という_こと_ない
# 1       0   3135               0_ください_でしょ_よろしい_大臣
# 2       1   1425                 1_雇用_賃上げ_賃金_最低賃金
# 3       2   1386                2_接種_ワクチン_副反応_高齢者
# 4       3   1006                  3_消費税_課税_税制_法人税
# 5       4    859                    4_病院_医療_医師_患者
# 6       5    725                5_ありがとう_ござい_まし_拍手
# 7       6    669                 6_予算_補正予算_予備費_経費
# 8       7    641                    7_学校_教員_学級_研修
# 9       8    629                   8_原発_原子力_規制_稼働
# 10      9    590                9_ウクライナ_ロシア_侵略_侵攻
# 11     10    537                 10_自治体_地方_地域_市町村
# 12     11    519                11_感染_感染者_感染拡大_検査
# 13     12    342               12_住宅_家賃_空き家_マンション
# 14     13    339                  13_農業_農地_農家_担い手
# 15     14    335              14_デジタル_デジタル化_社会_it
# 16     15    323  15_新型コロナウイルス_新型コロナウイルス感染症_感染_対策
# 17     16    316                   16_交通_道路_鉄道_国道
# 18     17    295           17_炭素_カーボンニュートラル_排出_目標
# 19     18    289                  18_年金_負担_保険料_現役
# 20     19    288               19_緊急事態宣言_解除_延長_蔓延
# 21     20    279                  20_皆様_理事_感謝_ござい
# 22     21    275                21_北朝鮮_韓国_発射_拉致問題
# 23     22    275                  22_中国_台湾_日本_習近平
# 24     23    274                  23_土地_所有者_不明_相続
# 25     24    270                 24_nhk_受信料_放送_会長
# 26     25    252                  25_裁判_判決_裁判官_審理
# 27     26    247                   26_総理_大臣_答弁_会長
# 28     27    238                      27_終わり_ます__
# 29     28    235                   28_治水_河川_ダム_流域
